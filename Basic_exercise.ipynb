# %% [markdown]
# <a href="https://colab.research.google.com/github/Omkar-Saple/Python_DSpractice/blob/main/Basic_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name= "omkar"

# %%
print(name)
# Out:
# omkar

# %%
print(name.upper())
print(name.lower())
print(name.title())
# Out:
# OMKAR
# omkar
# Omkar

# %%
text = "i am learning java"
text.replace("java", "python")
# Out:
# 'i am learning python'

# %%
text = "banana"
text.count("a")
# Out:
# 3

# %%
text = "Data Science"
text.find("Science")
# Out:
# 5

# %%
text = "   Python   "
text.strip()
# Out:
# 'Python'

# %%
text = "Python is easy"
text.split()
# Out:
# ['Python', 'is', 'easy']

# %%
data = "AI,ML,Data Science"
data.split(",")
# Out:
# ['AI', 'ML', 'Data Science']

# %%
from os.path import join
words = ["Python", "is", "awesome"]
print(" ".join(words))
data = ["2026", "05", "27"]
print("-".join(data))
# Out:
# Python is awesome
# 2026-05-27

# %%
names = ["Rahul", "Aman", "Priya"]
print(",".join(names))
# Out:
# Rahul,Aman,Priya

# %%
name = "Manoj"
age = 21
print(f"my name is {name} and i am {age} year old")
# Out:
# my name is Manoj and i am 21 year old

# %%
price = 99.4567
print(f"{price:.2f}")
# Out:
# 99.46

# %%
student = "Rahul"
marks = 88
print(f"{student} score {marks} marks")
# Out:
# Rahul score 88 marks

# %%
name = "   MANOJ PATIL   "

clean_name = name.strip().title()

print(clean_name)
# Out:
# Manoj Patil

# %%
text = "machine learning model"

words = text.split()

result = "-".join(words)

print(result)
# Out:
# machine-learning-model

# %%
file = "report.pdf"

print(file.endswith(".pdf"))
# Out:
# True
